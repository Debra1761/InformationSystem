# %%
# !pip install xmltodict

# %%
import requests 

x = requests.get('https://rss.nytimes.com/services/xml/rss/nyt/World.xml')

# %%
x.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<rss xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:media="http://search.yahoo.com/mrss/" xmlns:atom="http://www.w3.org/2005/Atom" xmlns:nyt="http://www.nytimes.com/namespaces/rss/2.0" version="2.0">\n  <channel>\n    <title>NYT &gt; World News</title>\n    <link>https://www.nytimes.com/section/world</link>\n    <atom:link href="https://rss.nytimes.com/services/xml/rss/nyt/World.xml" rel="self" type="application/rss+xml"></atom:link>\n    <description></description>\n    <language>en-us</language>\n    <copyright>Copyright 2020 The New York Times Company</copyright>\n    <lastBuildDate>Wed, 02 Sep 2020 12:25:05 +0000</lastBuildDate>\n    <pubDate>Wed, 02 Sep 2020 12:25:05 +0000</pubDate>\n    \n      <title>NYT &gt; World News</title>\n      <url>https://static01.nyt.com/images/misc/NYT_logo_rss_250x40.png</url>\n      <link>https://www.nytimes.com/section/world</link>\n    \n    <item>\n      <title>Kashmir&#39;s Moderates Are Targeted by 
# ...

# %%
import xmltodict, json

r = xmltodict.parse(x.text)
# r = json.dumps(r) # '{"e": {"a": ["text", "text"]}}’

# %%
for x in r['rss']['channel']['item']:
    print(x['link'])
    break
# Out:
# https://www.nytimes.com/2020/09/01/world/asia/india-kashmir-moderates.html
# https://www.nytimes.com/2020/09/01/world/americas/Jaguars-argentina-ibera.html
# https://www.nytimes.com/2020/09/02/world/europe/kremlin-putin-navalny-poisoning-russia.html
# https://www.nytimes.com/2020/09/01/world/europe/charlie-hebdo-cartoons-trial-france.html
# https://www.nytimes.com/2020/09/01/world/asia/duch-kaing-guek-eav-dead.html
# https://www.nytimes.com/2020/09/01/world/canada/john-macdonald-statue-quebec-montreal.html
# https://www.nytimes.com/2020/09/01/world/africa/rwanda-paul-rusesabagina-kidnapped.html
# https://www.nytimes.com/2020/09/01/world/schools-reopen-globe-students.html
# https://www.nytimes.com/2020/09/01/world/middleeast/lebanon-macron-sanctions.html
# https://www.nytimes.com/2020/09/02/world/europe/charlie-hebdo-trial-france.html
# https://www.nytimes.com/2020/09/02/briefing/ed-markey-jet-pack-khmer-rouge-your-wednesday-briefing.html
# ...

# %%
hash("https://www.nytimes.com/2020/09/01/world/asia/india-kashmir-moderates.html")
# Out:
# 6416808635808393191
